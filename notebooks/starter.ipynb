# %% [markdown]
# # PlaceMux Task 1 — Starter Notebook
# This notebook is intentionally thin. All real logic lives in `src/` so nothing is trapped inside notebook cells.

# %%
import sys
sys.path.append('..')

from src.smoke_test import main

# %%
main()
